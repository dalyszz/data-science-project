# %% [markdown]
# <a href="https://colab.research.google.com/github/dalyszz/data-science-project/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://data.cdc.gov/api/views/hfr9-rurv/rows.csv?accessType=DOWNLOAD"
df = pd.read_csv(url)
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#                                       RowId  YearStart  YearEnd LocationAbbr  \
# 0      BRFSS~2015~2015~66~Q35~TOC03~AGE~SEX       2015     2015           GU
# 1      BRFSS~2015~2015~25~Q27~TMC03~AGE~SEX       2015     2015           MA
# 2    BRFSS~2015~2015~9002~Q43~TOC11~AGE~SEX       2015     2015          MDW
# 3      BRFSS~2015~2015~27~Q03~TMC01~AGE~SEX       2015     2015           MN
# 4  BRFSS~2015~2015~29~Q43~TOC11~AGE~OVERALL       2015     2015           MO
#
#     LocationDesc Datasource           Class  \
# 0           Guam      BRFSS  Overall Health
# 1  Massachusetts      BRFSS   Mental Health
# 2        Midwest      BRFSS  Overall Health
# 3      Minnesota      BRFSS   Mental Health
# 4       Missouri      BRFSS  Overall Health
#
#                                        Topic  \
# 0  Recent activity limitations in past month
# 1           Lifetime diagnosis of depression
# 2               Arthritis among older adults
# 3                   Frequent mental distress
# ...

# %%
df.columns = ([
    'Row Id','Year Start', 'Year End', 'Location Abbreviated',
    'Location Description', 'Data Source', 'Class', 'Topic', 'Question',
    'Data Value Unit', 'Data Value Type ID', 'Data Value Type',
    'Data Value', 'Data Value Alt','Data Value Footnote Symbol',
    'Data Value Footnote','Low Confidence Limit',
    'High Confidence Limit','Stratification Category 1',
    'Stratification 1', 'Stratification Category 2','Stratification 2',
    'Geolocation', 'Class ID', 'Topic ID', 'Question ID', 'Location ID',
    'Stratification Category ID1', 'Stratification ID1',
    'Stratification Category ID2', 'Stratification ID2'
])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284142 entries, 0 to 284141
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Row Id                       284142 non-null  object
#  1   Year Start                   284142 non-null  int64
#  2   Year End                     284142 non-null  int64
#  3   Location Abbreviated         284142 non-null  object
#  4   Location Description         284142 non-null  object
#  5   Data Source                  284142 non-null  object
#  6   Class                        284142 non-null  object
#  7   Topic                        284142 non-null  object
#  8   Question                     284142 non-null  object
#  9   Data Value Unit              284142 non-null  object
#  10  Data Value Type ID           284142 non-null  object
#  11  Data Value Type              284142 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Row Id                              0
# Year Start                          0
# Year End                            0
# Location Abbreviated                0
# Location Description                0
# Data Source                         0
# Class                               0
# Topic                               0
# Question                            0
# Data Value Unit                     0
# Data Value Type ID                  0
# Data Value Type                     0
# Data Value                      91334
# Data Value Alt                  91334
# Data Value Footnote Symbol     174166
# Data Value Footnote            174166
# Low Confidence Limit            91545
# High Confidence Limit           91545
# Stratification Category 1           0
# Stratification 1                    0
# Stratification Category 2       36873
# Stratification 2                36873
# Geolocation                     30489
# Class ID                            0
# Topic ID                            0
# ...

# %%
print(df.shape)
# Out:
# (284142, 31)

# %%
(df.isnull().sum() / len(df) * 100).sort_values(ascending=False)
# Out:
# Data Value Footnote Symbol     61.295409
# Data Value Footnote            61.295409
# Low Confidence Limit           32.218046
# High Confidence Limit          32.218046
# Data Value                     32.143787
# Data Value Alt                 32.143787
# Stratification Category 2      12.976962
# Stratification 2               12.976962
# Geolocation                    10.730198
# Class                           0.000000
# Data Source                     0.000000
# Location Abbreviated            0.000000
# Row Id                          0.000000
# Year Start                      0.000000
# Year End                        0.000000
# Data Value Type                 0.000000
# Question                        0.000000
# Data Value Unit                 0.000000
# Data Value Type ID              0.000000
# Topic                           0.000000
# Location Description            0.000000
# Stratification Category 1       0.000000
# Stratification 1                0.000000
# ...

# %%
columns_to_drop = [
    'Row Id',
    'Class ID',
    'Topic ID',
    'Question ID',
    'Data Value Unit',
    'Data Value Type ID',
    'Data Value Alt',
    'Data Value Footnote Symbol',
    'Location ID',
    'Stratification Category 1',
    'Stratification Category ID1',
    'Stratification ID1',
    'Stratification Category ID2',
    'Stratification ID2'
]

df = df.drop(columns=columns_to_drop)

# %%
print(df.columns)
# Out:
# Index(['Year Start', 'Year End', 'Location Abbreviated',
#        'Location Description', 'Data Source', 'Class', 'Topic', 'Question',
#        'Data Value Type', 'Data Value', 'Data Value Footnote',
#        'Low Confidence Limit', 'High Confidence Limit', 'Stratification 1',
#        'Stratification Category 2', 'Stratification 2', 'Geolocation'],
#       dtype='object')

# %%
df.head()
# Out:
#    Year Start  Year End Location Abbreviated Location Description Data Source  \
# 0        2015      2015                   GU                 Guam       BRFSS
# 1        2015      2015                   MA        Massachusetts       BRFSS
# 2        2015      2015                  MDW              Midwest       BRFSS
# 3        2015      2015                   MN            Minnesota       BRFSS
# 4        2015      2015                   MO             Missouri       BRFSS
#
#             Class                                      Topic  \
# 0  Overall Health  Recent activity limitations in past month
# 1   Mental Health           Lifetime diagnosis of depression
# 2  Overall Health               Arthritis among older adults
# 3   Mental Health                   Frequent mental distress
# 4  Overall Health               Arthritis among older adults
#
#                                             Question Data Value Type  \
# ...
